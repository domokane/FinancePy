# %% [markdown]
# # Creating and Valuing a CDS Index

# %% [markdown]
# Example CDS Index Valuation

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from financepy.utils.date import Date
from financepy.utils.global_vars import ONE_MILLION
from financepy.utils.day_count import DayCountTypes
from financepy.utils.frequency import FrequencyTypes

from financepy.products.rates.ibor_deposit import IborDeposit
from financepy.products.rates.ibor_swap import IborSwap, SwapTypes
from financepy.products.credit.cds import CDS

from financepy.market.curves.cds_curve import CDSCurve
from financepy.market.curves.ibor_single_curve import IborSingleCurve
# Out:
# #############################################################
# #  FINANCEPY Version 1.1.2 - Built on 18 Sep 2026 at 20:26  #
# #  This software is distributed FREE AND WITHOUT WARRANTY   #
# #  Report issues at https://github.com/domokane/FinancePy   #
# #############################################################

# %%
value_dt = Date(7, 2, 2006)
settle_dt = value_dt.add_weekdays(0)
print(settle_dt)
# Out:
# 07-FEB-2006

# %% [markdown]
# ## Build Ibor Curve

# %% [markdown]
# Build the Ibor curve to value cash flows

# %%
depos = []
dc_type = DayCountTypes.THIRTY_E_360_ISDA
fixed_freq = FrequencyTypes.SEMI_ANNUAL
swap_type = SwapTypes.PAY
swap1 = IborSwap(settle_dt,"1Y",swap_type,0.0502,fixed_freq,dc_type)
swap2 = IborSwap(settle_dt,"2Y",swap_type,0.0502,fixed_freq,dc_type)
swap3 = IborSwap(settle_dt,"3Y",swap_type,0.0501,fixed_freq,dc_type)
swap4 = IborSwap(settle_dt,"4Y",swap_type,0.0502,fixed_freq,dc_type)
swap5 = IborSwap(settle_dt,"5Y",swap_type,0.0501,fixed_freq,dc_type)
swaps = [swap1,swap2,swap3,swap4,swap5]

libor_curve = IborSingleCurve(value_dt, depos, [], swaps)

# %% [markdown]
# ## Build Index Curve

# %% [markdown]
# We treat an index as a CDS contract with a flat CDS curve at the CDS index spread for the same maturity

# %%
step_in_dt = value_dt

# %%
index_cpn = 0.0048375
maturity_dt = Date(20, 6, 2010)

cds_mkt_contracts = []
cds = CDS(value_dt, maturity_dt, index_cpn)
cds_mkt_contracts.append(cds)

recovery_rate = 0.40
index_curve = CDSCurve(value_dt, cds_mkt_contracts,libor_curve,recovery_rate)

# %% [markdown]
# ## Create CDS Index and Perform Valuation

# %% [markdown]
# The CDS Index is treated as a CDS with the cpn equal to the CDS Index cpn

# %%
cds_recovery = 0.40
notional = 10.0 * ONE_MILLION
long_protection = True
index_cpn = 0.004

cdsIndexContract = CDS(step_in_dt, maturity_dt, index_cpn, notional, long_protection)

# %%
spd = cdsIndexContract.par_spread(value_dt, index_curve, cds_recovery) * 10000
print("PAR SPREAD", spd)
# Out:
# PAR SPREAD 48.37499999998472

# %%
v = cdsIndexContract.value(value_dt, index_curve, cds_recovery)
print("DIRTY VALUE", v[0])
print("CLEAN VALUE", v[1])
# Out:
# DIRTY VALUE 27195.793918285635
# CLEAN VALUE 32640.238362730073

# %%
p = cdsIndexContract.clean_price(value_dt, index_curve, cds_recovery)
print("CLEAN PRICE", p)
# Out:
# CLEAN PRICE 99.6735976163727

# %%
accrued_days = cdsIndexContract.accrued_days(value_dt)
print("ACCRUED DAYS", accrued_days)

accrued_interest = cdsIndexContract.accrued_interest(value_dt)
print("ACCRUED COUPON", accrued_interest)
# Out:
# ACCRUED DAYS 49.0
# ACCRUED COUPON 5444.444444444444

# %%
prot_pv = cdsIndexContract.prot_leg_pv(value_dt, index_curve, cds_recovery)
print("PROTECTION LEG PV", prot_pv)
# Out:
# PROTECTION LEG PV 188533.9141253073

# %%
premPV = cdsIndexContract.premium_leg_pv(value_dt, index_curve)
print("PREMIUM LEG PV", premPV)
# Out:
# PREMIUM LEG PV 161338.12020702165

# %%
rpv01 = cdsIndexContract.rpv01(value_dt, index_curve)
print("DIRTY RPV01", rpv01[0])
print("CLEAN RPV01", rpv01[1])
# Out:
# DIRTY RPV01 4.0334530051755415
# CLEAN RPV01 3.8973418940644304

# %% [markdown]
# Copyright (c) 2020 Dominic O'Kane
