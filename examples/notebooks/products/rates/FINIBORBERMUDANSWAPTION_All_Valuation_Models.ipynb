# %% [markdown]
# # Bermudan Swaption Pricing

# %% [markdown]
# Value a European Swaption using the Hull-White, Black-Derman-Toy and Black-Karasinski models. I analyse relationships to test the model pricing.

# %% [markdown]
# NOTE SENSITIVE TO EVEN-ODD NUMBER OF TIME STEPS ON TREE - INVESTIGATE

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from financepy.utils.date import Date
from financepy.utils.global_vars import ONE_MILLION
from financepy.utils.day_count import DayCountTypes
from financepy.utils.frequency import FrequencyTypes
from financepy.utils.calendar import CalendarTypes, BusDayAdjustTypes, DateGenRuleTypes

from financepy.market.curves.interpolator import InterpTypes
from financepy.market.curves.ibor_single_curve import IborSingleCurve
from financepy.market.curves.flat_discount_curve import FlatDiscountCurve
from financepy.market.curves.zero_rates_discount_curve import ZeroRatesDiscountCurve

from financepy.products.rates.ibor_deposit import IborDeposit
from financepy.products.rates.ibor_swap import IborSwap, SwapTypes
from financepy.products.rates.ibor_swaption import IborSwaption, BlackShifted, Black, SABR, SABRShifted, HWTree, BKTree, BDTTree
from financepy.products.rates.ibor_bermudan_swaption import IborBermudanSwaption, BDTTree, BKTree, HWTree, ExerciseTypes
# Out:
# #############################################################
# #  FINANCEPY Version 1.1.2 - Built on 18 Sep 2026 at 20:26  #
# #  This software is distributed FREE AND WITHOUT WARRANTY   #
# #  Report issues at https://github.com/domokane/FinancePy   #
# #############################################################

# %% [markdown]
# ## Discount Curve

# %%
value_dt = Date(1, 1, 2011)
settle_dt = value_dt

# %% [markdown]
# Set up flat discount curve

# %%
rate = 0.0625
libor_curve = FlatDiscountCurve(value_dt,
                                  rate,
                                  FrequencyTypes.SEMI_ANNUAL,
                                  DayCountTypes.ACT_365F)

# %% [markdown]
# # The Underlying Swap

# %% [markdown]
# We begin with the underlying swap.

# %%
exercise_dt = settle_dt.add_years(1)
swap_maturity_dt = settle_dt.add_years(4)
swap_fixed_cpn = 0.060
swap_fixed_freq_type = FrequencyTypes.SEMI_ANNUAL
swapFixedDayCountType = DayCountTypes.ACT_365F
swap_type = SwapTypes.PAY

# %% [markdown]
# We can value the forward starting swap.

# %%
swap = IborSwap(exercise_dt,
                    swap_maturity_dt,
                    swap_type,
                    swap_fixed_cpn,
                    swap_fixed_freq_type,
                    swapFixedDayCountType)

# %% [markdown]
# We can approximate the value using 2.5 as the approximate duration of a 3 year swap

# %%
(rate - swap_fixed_cpn) * 2.5 * ONE_MILLION
# Out:
# 6250.0000000000055

# %%
swapValue = swap.value(value_dt, libor_curve, libor_curve)
print("Swap Value: %9.5f"% swapValue)
# Out:
# Swap Value: 6348.48951

# %% [markdown]
# The estimate was not bad !

# %%
swap.print_fixed_leg_pv()
# Out:
# START DATE: 01-JAN-2012
# MATURITY DATE: 01-JAN-2015
# COUPON (%): 6.0
# FREQUENCY: FrequencyTypes.SEMI_ANNUAL
# DAY COUNT: DayCountTypes.ACT_365F
#
# PAYMENTS VALUATION:
# PAY_NUM | PAY_dt      | NOTIONAL | RATE | PMNT     | DF     | PV       | CUM_PV
# --------+-------------+----------+------+----------+--------+----------+----------
#       1 | 02-JUL-2012 |  1000000 |  6.0 | 30082.19 | 0.9117 | 27427.17 |  27427.17
#       2 | 01-JAN-2013 |  1000000 |  6.0 | 30082.19 |  0.884 |  26593.8 |  54020.97
#       3 | 01-JUL-2013 |  1000000 |  6.0 | 29753.42 | 0.8575 | 25512.54 |  79533.51
#       4 | 01-JAN-2014 |  1000000 |  6.0 | 30246.58 | 0.8313 | 25143.12 | 104676.64
#       5 | 01-JUL-2014 |  1000000 |  6.0 | 29753.42 | 0.8063 | 23989.76 | 128666.39
#       6 | 01-JAN-2015 |  1000000 |  6.0 | 30246.58 | 0.7817 | 23642.39 | 152308.78

# %%
swap.print_float_leg_pv()
# Out:
# START DATE: 01-JAN-2012
# MATURITY DATE: 01-JAN-2015
# SPREAD (BPS): 0.0
# FREQUENCY: FrequencyTypes.QUARTERLY
# ACCRUAL_DC: DayCountTypes.THIRTY_E_360
#
# PAYMENTS VALUATION:
# PAY_NUM | PAY_dt      | NOTIONAL | IBOR   | PMNT     | DF     | PV       | CUM_PV
# --------+-------------+----------+--------+----------+--------+----------+----------
#       1 | 02-APR-2012 |  1000000 | 6.1846 | 15633.23 | 0.9258 | 14473.84 |  14473.84
#       2 | 02-JUL-2012 |  1000000 | 6.1848 | 15461.99 | 0.9117 | 14097.34 |  28571.18
#       3 | 01-OCT-2012 |  1000000 | 6.2543 | 15461.99 | 0.8979 | 13882.68 |  42453.86
#       4 | 01-JAN-2013 |  1000000 | 6.2533 | 15633.23 |  0.884 | 13820.37 |  56274.23
#       5 | 01-APR-2013 |  1000000 | 6.1163 | 15290.79 | 0.8707 | 13314.06 |  69588.28
#       6 | 01-JUL-2013 |  1000000 | 6.1848 | 15461.99 | 0.8575 | 13258.13 |  82846.42
#       7 | 01-OCT-2013 |  1000000 | 6.2533 | 15633.23 | 0.8443 | 13198.62 |  96045.04
#       8 | 01-JAN-2014 |  1000000 | 6.2533 | 15633.23 | 0.8313 | 12995.46 |  109040.5
#       9 | 01-APR-2014 |  1000000 | 6.1163 | 15290.79 | 0.8188 | 12519.37 | 121559.87
#      10 | 01-JUL-2014 |  1000000 | 6.1848 | 15461.99 | 0.8063 | 12466.78 | 134026.65
#      11 | 01-OCT-2014 |  1000000 | 6.2533 | 15633.23 | 0.7939 | 12410.82 | 146437.48
#      12 | 01-JAN-2015 |  1000000 | 6.2533 | 15633.23 | 0.7817 | 12219.79 | 158657.27

# %% [markdown]
# # IborSwaption

# %% [markdown]
# This is a class for European-style swaptions. It implements a number of model implementations.

# %%
european_swaption_pay = IborSwaption(settle_dt,
                                      exercise_dt,
                                      swap_maturity_dt,
                                      SwapTypes.PAY,
                                      swap_fixed_cpn,
                                      swap_fixed_freq_type,
                                      swapFixedDayCountType)

# %%
european_swaption_rec = IborSwaption(settle_dt,
                                      exercise_dt,
                                      swap_maturity_dt,
                                      SwapTypes.RECEIVE,
                                      swap_fixed_cpn,
                                      swap_fixed_freq_type,
                                      swapFixedDayCountType)

# %%
european_swaption_pay
# Out:
# OBJECT_TYPE: IborSwaption
# SETTLEMENT DATE: 01-JAN-2011
# EXERCISE DATE: 01-JAN-2012
# SWAP FIXED LEG TYPE: SwapTypes.PAY
# SWAP MATURITY DATE: 01-JAN-2015
# SWAP NOTIONAL: 1000000
# FIXED cpn: 6.0
# FIXED FREQUENCY: FrequencyTypes.SEMI_ANNUAL
# FIXED DAY COUNT: DayCountTypes.ACT_365F
# FLOAT FREQUENCY: FrequencyTypes.QUARTERLY
# FLOAT DAY COUNT: DayCountTypes.THIRTY_E_360

# %% [markdown]
# Set the volatility to zero so that payer is pure intrinsic

# %% [markdown]
# ### Black's Model

# %%
sigma = 0.00001

# %%
model = Black(sigma)

# %%
european_swaption_pay.value(value_dt, libor_curve, model)
# Out:
# np.float64(6348.4895087776395)

# %% [markdown]
# Let's check for put-call parity

# %%
sigma = 0.20

# %%
model = Black(sigma)

# %%
value_pay = european_swaption_pay.value(value_dt, libor_curve, model)
value_rec = european_swaption_rec.value(value_dt, libor_curve, model)
value_pay_rec = value_pay - value_rec
print("PAY Value: %9.5f"% value_pay)
print("REC Value: %9.5f"% value_rec)
print("PAY - REC: %9.5f"% value_pay_rec)
# Out:
# PAY Value: 15815.70649
# REC Value: 9467.21698
# PAY - REC: 6348.48951

# %% [markdown]
# Yes put-call parity is respected.

# %% [markdown]
# ### BK Model

# %%
a = 0.01
sigma = 0.0000001
num_time_steps = 100
model = BKTree(sigma, a, num_time_steps)

# %%
value_pay = european_swaption_pay.value(value_dt, libor_curve, model)
value_rec = european_swaption_rec.value(value_dt, libor_curve, model)
value_pay_rec = value_pay - value_rec
print("PAY Value: %9.5f"% value_pay)
print("REC Value: %9.5f"% value_rec)
print("PAY - REC: %9.5f"% value_pay_rec)
# Out:
# PAY Value: 6346.08093
# REC Value:   0.00000
# PAY - REC: 6346.08093

# %%
a = 0.01
sigma = 0.20
num_time_steps = 100
model = BKTree(sigma, a, num_time_steps)

# %%
value_pay = european_swaption_pay.value(value_dt, libor_curve, model)
value_rec = european_swaption_rec.value(value_dt, libor_curve, model)
value_pay_rec = value_pay - value_rec
print("PAY Value: %9.5f"% value_pay)
print("REC Value: %9.5f"% value_rec)
print("PAY - REC: %9.5f"% value_pay_rec)
# Out:
# PAY Value: 15746.57475
# REC Value: 9400.49421
# PAY - REC: 6346.08054

# %% [markdown]
# ### BDT Model

# %%
sigma = 0.0000001
num_time_steps = 200
model = BDTTree(sigma, num_time_steps)

# %%
value_pay = european_swaption_pay.value(value_dt, libor_curve, model)
value_rec = european_swaption_rec.value(value_dt, libor_curve, model)
value_pay_rec = value_pay - value_rec
print("PAY Value: %9.5f"% value_pay)
print("REC Value: %9.5f"% value_rec)
print("PAY - REC: %9.5f"% value_pay_rec)
# Out:
# PAY Value: 6347.52034
# REC Value:   0.00000
# PAY - REC: 6347.52034

# %%
sigma = 0.20
model = BDTTree(sigma, num_time_steps)

# %%
value_pay = european_swaption_pay.value(value_dt, libor_curve, model)
value_rec = european_swaption_rec.value(value_dt, libor_curve, model)
value_pay_rec = value_pay - value_rec
print("PAY Value: %9.5f"% value_pay)
print("REC Value: %9.5f"% value_rec)
print("PAY - REC: %9.5f"% value_pay_rec)
# Out:
# PAY Value: 15989.23693
# REC Value: 9641.71659
# PAY - REC: 6347.52034

# %% [markdown]
# ### HW Model

# %%
sigma = 0.0000001
num_time_steps = 200
a = 0.01
model = HWTree(sigma, a, num_time_steps)

# %%
value_pay = european_swaption_pay.value(value_dt, libor_curve, model)
value_rec = european_swaption_rec.value(value_dt, libor_curve, model)
value_pay_rec = value_pay - value_rec
print("PAY Value: %9.5f"% value_pay)
print("REC Value: %9.5f"% value_rec)
print("PAY - REC: %9.5f"% value_pay_rec)
# Out:
# PAY Value: 6348.45763
# REC Value:   0.00000
# PAY - REC: 6348.45763

# %%
sigma = 0.20 * rate
num_time_steps = 200
a = 0.01
model = HWTree(sigma, a, num_time_steps)

# %%
value_pay = european_swaption_pay.value(value_dt, libor_curve, model)
value_rec = european_swaption_rec.value(value_dt, libor_curve, model)
value_pay_rec = value_pay - value_rec
print("PAY Value: %9.5f"% value_pay)
print("REC Value: %9.5f"% value_rec)
print("PAY - REC: %9.5f"% value_pay_rec)
# Out:
# PAY Value: 16217.69298
# REC Value: 9869.43817
# PAY - REC: 6348.25481

# %% [markdown]
# # IborBermudanSwaption

# %% [markdown]
# I now examine FinBermudanSwaption and use the tree models to value it. But first let me price it on the tree models as a European option.

# %% [markdown]
# ## Start By Only Allowing European Exercise

# %%
europeanBermSwaptionPay = IborBermudanSwaption(settle_dt,
                                                  exercise_dt,
                                                  swap_maturity_dt,
                                                  SwapTypes.PAY,
                                                  ExerciseTypes.EUROPEAN,
                                                  swap_fixed_cpn,
                                                  swap_fixed_freq_type,
                                                  swapFixedDayCountType)

# %%
europeanBermSwaptionRec = IborBermudanSwaption(settle_dt,
                                                  exercise_dt,
                                                  swap_maturity_dt,
                                                  SwapTypes.RECEIVE,
                                                  ExerciseTypes.EUROPEAN,
                                                  swap_fixed_cpn,
                                                  swap_fixed_freq_type,
                                                  swapFixedDayCountType)

# %% [markdown]
# ### Black Karasinski Model

# %% [markdown]
# Setting the volatility close to zero so we only have intrinsic value.

# %%
black_vol = 0.0000001

# %%
sigma = black_vol
a = 0.01
num_time_steps = 200
model = BKTree(sigma, a, num_time_steps)

# %%
value_pay = europeanBermSwaptionPay.value(value_dt, libor_curve, model)
value_rec = europeanBermSwaptionRec.value(value_dt, libor_curve, model)
value_pay_rec = value_pay - value_rec
print("PAY Value: %9.5f"% value_pay)
print("REC Value: %9.5f"% value_rec)
print("PAY - REC: %9.5f"% value_pay_rec)
# Out:
# PAY Value: 6313.74545
# REC Value:   0.00000
# PAY - REC: 6313.74545

# %%
europeanBermSwaptionPay.print_swaption_value()
# Out:
# SWAP PV01: 2.538479623216061
# CPN TIME:  1.0 PAYMENT 0.0
# CPN TIME:  1.5013698630136987 PAYMENT 0.030246575342465755
# CPN TIME:  2.0027397260273974 PAYMENT 0.03008219178082192
# CPN TIME:  2.4986301369863013 PAYMENT 0.03008219178082192
# CPN TIME:  3.0027397260273974 PAYMENT 0.029753424657534246
# CPN TIME:  3.4986301369863013 PAYMENT 0.030246575342465755
# CPN TIME:  4.002739726027397 PAYMENT 0.029753424657534246
# CALL TIME:  1.0
# CALL TIME:  1.5013698630136987
# CALL TIME:  2.0027397260273974
# CALL TIME:  2.4986301369863013
# CALL TIME:  3.0027397260273974
# CALL TIME:  3.4986301369863013
# CALL TIME:  4.002739726027397

# %% [markdown]
# ### Black Derman Toy Model

# %%
sigma = 0.0000001
num_time_steps = 100
model = BDTTree(sigma, num_time_steps)

# %%
value_pay = europeanBermSwaptionPay.value(value_dt, libor_curve, model)
value_rec = europeanBermSwaptionRec.value(value_dt, libor_curve, model)
value_pay_rec = value_pay - value_rec
print("PAY Value: %9.5f"% value_pay)
print("REC Value: %9.5f"% value_rec)
print("PAY - REC: %9.5f"% value_pay_rec)
# Out:
# PAY Value: 6312.29817
# REC Value:   0.00000
# PAY - REC: 6312.29817

# %%
sigma = 0.20
num_time_steps = 100
model = BDTTree(sigma, num_time_steps)

# %%
value_pay = europeanBermSwaptionPay.value(value_dt, libor_curve, model)
value_rec = europeanBermSwaptionRec.value(value_dt, libor_curve, model)
value_pay_rec = value_pay - value_rec
print("PAY Value: %9.5f"% value_pay)
print("REC Value: %9.5f"% value_rec)
print("PAY - REC: %9.5f"% value_pay_rec)
# Out:
# PAY Value: 15934.56416
# REC Value: 9622.26599
# PAY - REC: 6312.29817

# %% [markdown]
# ### Hull White Model

# %%
sigma = 0.0000001
a = 0.01
num_time_steps = 101
model = HWTree(sigma, a, num_time_steps)

# %%
value_pay = europeanBermSwaptionPay.value(value_dt, libor_curve, model)
value_rec = europeanBermSwaptionRec.value(value_dt, libor_curve, model)
value_pay_rec = value_pay - value_rec
print("PAY Value: %9.5f"% value_pay)
print("REC Value: %9.5f"% value_rec)
print("PAY - REC: %9.5f"% value_pay_rec)
# Out:
# PAY Value: 6314.50332
# REC Value:   0.00000
# PAY - REC: 6314.50332

# %%
sigma = 0.20 * rate
a = 0.01
num_time_steps = 101
model = HWTree(sigma, a, num_time_steps)

# %%
value_pay = europeanBermSwaptionPay.value(value_dt, libor_curve, model)
value_rec = europeanBermSwaptionRec.value(value_dt, libor_curve, model)
value_pay_rec = value_pay - value_rec
print("PAY Value: %9.5f"% value_pay)
print("REC Value: %9.5f"% value_rec)
print("PAY - REC: %9.5f"% value_pay_rec)
# Out:
# PAY Value: 16237.06135
# REC Value: 9922.55803
# PAY - REC: 6314.50332

# %% [markdown]
# # Now allow Multiple Exercise Dates - Bermudan

# %% [markdown]
# Now allow exercise on ALL cpn dates PLUS expiry.

# %%
bermudan_swaption_pay = IborBermudanSwaption(settle_dt,
                                               exercise_dt,
                                               swap_maturity_dt,
                                               SwapTypes.PAY,
                                               ExerciseTypes.BERMUDAN,
                                               swap_fixed_cpn,
                                               swap_fixed_freq_type,
                                               swapFixedDayCountType)

# %%
bermudan_swaption_rec = IborBermudanSwaption(settle_dt,
                                               exercise_dt,
                                               swap_maturity_dt,
                                               SwapTypes.RECEIVE,
                                               ExerciseTypes.BERMUDAN,
                                               swap_fixed_cpn,
                                               swap_fixed_freq_type,
                                               swapFixedDayCountType)

# %% [markdown]
# ### Black Karasinski Model

# %%
sigma = 0.20
a = 0.01
num_time_steps = 100
model = BKTree(sigma, a, num_time_steps)

# %%
value_pay = bermudan_swaption_pay.value(value_dt, libor_curve, model)
value_rec = bermudan_swaption_rec.value(value_dt, libor_curve, model)
value_pay_rec = value_pay - value_rec
print("PAY Value: %9.5f"% value_pay)
print("REC Value: %9.5f"% value_rec)
print("PAY - REC: %9.5f"% value_pay_rec)
# Out:
# PAY Value: 19235.85760
# REC Value: 13043.39490
# PAY - REC: 6192.46270

# %% [markdown]
# ### Black-Derman-Toy Model

# %%
sigma = 0.20
num_time_steps = 100
model = BDTTree(sigma, num_time_steps)

# %%
value_pay = bermudan_swaption_pay.value(settle_dt, libor_curve, model)
value_rec = bermudan_swaption_rec.value(settle_dt, libor_curve, model)
value_pay_rec = value_pay - value_rec
print("PAY Value: %9.5f"% value_pay)
print("REC Value: %9.5f"% value_rec)
print("PAY - REC: %9.5f"% value_pay_rec)
# Out:
# PAY Value: 19497.23457
# REC Value: 13321.96480
# PAY - REC: 6175.26976

# %% [markdown]
# ### Hull-White Model

# %%
sigma = 0.01
a = 0.01
num_time_steps = 100
model = HWTree(sigma, a)

# %%
value_pay = bermudan_swaption_pay.value(settle_dt, libor_curve, model)
value_rec = bermudan_swaption_rec.value(settle_dt, libor_curve, model)
value_pay_rec = value_pay - value_rec
print("PAY Value: %9.5f"% value_pay)
print("REC Value: %9.5f"% value_rec)
print("PAY - REC: %9.5f"% value_pay_rec)
# Out:
# PAY Value: 16578.58987
# REC Value: 10406.29704
# PAY - REC: 6172.29283

# %% [markdown]
# The swaption is Bermudan so it can only be exercised on cpn payment dates

# %% [markdown]
# Copyright (c) 2020 Dominic O'Kane
