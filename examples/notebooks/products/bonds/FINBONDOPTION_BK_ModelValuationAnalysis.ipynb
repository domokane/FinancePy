# %% [markdown]
# # Bond Option Pricing using BK Model

# %% [markdown]
# Value an option on a coupon paying bond using the Black-Karasinski model

# %%
import numpy as np
import matplotlib.pyplot as plt
import time

# %%
from financepy.utils import *
from financepy.market.curves.flat_discount_curve import FlatDiscountCurve
from financepy.products.rates.ibor_swap import IborSwap
from financepy.market.curves.ibor_single_curve import IborSingleCurve
from financepy.models import *
from financepy.products.bonds.bond import *
from financepy.products.bonds.bond_option import *
from financepy.products.bonds.bond_embedded_option import *
# Out:
# #############################################################
# #  FINANCEPY Version 1.1.2 - Built on 25 Sep 2026 at 14:07  #
# #  This software is distributed FREE AND WITHOUT WARRANTY   #
# #  Report issues at https://github.com/domokane/FinancePy   #
# #############################################################

# %% [markdown]
# ## Bond Option Valuation

# %%
value_dt = Date(1, 12, 2019)
settle_dt = value_dt

# %% [markdown]
# Set up discount curve

# %%
dc_type = DayCountTypes.THIRTY_360_BOND
fixed_freq = FrequencyTypes.SEMI_ANNUAL
swap_type = SwapTypes.PAY
swap1 = IborSwap(settle_dt,"1Y",swap_type,0.0500,fixed_freq,dc_type)
swap2 = IborSwap(settle_dt,"3Y",swap_type,0.0500,fixed_freq,dc_type)
swap3 = IborSwap(settle_dt,"5Y",swap_type,0.0500,fixed_freq,dc_type)
swap4 = IborSwap(settle_dt,"7Y",swap_type,0.0500,fixed_freq,dc_type)
swap5 = IborSwap(settle_dt,"10Y",swap_type,0.0500,fixed_freq,dc_type)
swaps = [swap1, swap2, swap3, swap4, swap5]

libor_curve = IborSingleCurve(value_dt, [], [], swaps)

# %% [markdown]
# ## Set up the Bond Option

# %% [markdown]
# First create the bond

# %%
issue_dt = Date(1, 12, 2015)
maturity_dt = Date(1, 12, 2029)
coupon = 0.05
freq_type = FrequencyTypes.SEMI_ANNUAL
dc_type = DayCountTypes.THIRTY_360_BOND
bond = Bond(issue_dt, maturity_dt, coupon, freq_type, dc_type)

# %% [markdown]
# Let's first price the bond on the libor curve

# %%
price = bond.clean_price_from_discount_curve(settle_dt, libor_curve)
print("Fixed Income Price:", price)
# Out:
# Fixed Income Price: 99.98202295624777

# %% [markdown]
# Then define and create the option

# %%
expiry_dt = settle_dt.add_tenor("18m")
strike_price = 90.0
face = 100.0
opt_type = BondOptionTypes.AMERICAN_CALL

# %% [markdown]
# ### Black Karasinski Model

# %% [markdown]
# Set the model parameters

# %%
sigma = 0.20
a = 0.05
bkModel = BKTree(sigma, a)

# %%
strikes = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120])

# %%
for k in strikes:
    K = float(k)
    europeanCallBondOption = BondOption(bond, expiry_dt, K, OptionTypes.EUROPEAN_CALL)
    v_ec = europeanCallBondOption.value(settle_dt, libor_curve, bkModel)
    americanCallBondOption = BondOption(bond, expiry_dt, K, OptionTypes.AMERICAN_CALL)
    v_ac = americanCallBondOption.value(settle_dt, libor_curve, bkModel)
    europeanPutBondOption = BondOption(bond, expiry_dt, K, OptionTypes.EUROPEAN_PUT)
    v_ep = europeanPutBondOption.value(settle_dt, libor_curve, bkModel)
    americanPutBondOption = BondOption(bond, expiry_dt, K, OptionTypes.AMERICAN_PUT)
    v_ap = americanPutBondOption.value(settle_dt, libor_curve, bkModel)

    print("K: %9.5f EUR_CALL: %9.5f  AMER_CALL: %9.5f  EUR_PUT: %9.5f  AMER_PUT: %9.5f" %(K, v_ec, v_ac, v_ep, v_ap))
# Out:
# K:  80.00000 EUR_CALL:  18.57537  AMER_CALL:  19.99852  EUR_PUT:   0.01049  AMER_PUT:   0.01112
# K:  85.00000 EUR_CALL:  13.97986  AMER_CALL:  14.99852  EUR_PUT:   0.05831  AMER_PUT:   0.06174
# K:  90.00000 EUR_CALL:   9.51842  AMER_CALL:  10.17713  EUR_PUT:   0.24021  AMER_PUT:   0.26013
# K:  95.00000 EUR_CALL:   5.53859  AMER_CALL:   5.91679  EUR_PUT:   0.90372  AMER_PUT:   0.97566
# K: 100.00000 EUR_CALL:   2.44014  AMER_CALL:   2.63436  EUR_PUT:   2.44861  AMER_PUT:   2.65382
# K: 105.00000 EUR_CALL:   0.73585  AMER_CALL:   0.79616  EUR_PUT:   5.38766  AMER_PUT:   5.80922
# K: 110.00000 EUR_CALL:   0.11504  AMER_CALL:   0.12481  EUR_PUT:   9.41019  AMER_PUT:  10.12436
# K: 115.00000 EUR_CALL:   0.00672  AMER_CALL:   0.00721  EUR_PUT:  13.94521  AMER_PUT:  15.00148
# K: 120.00000 EUR_CALL:   0.00006  AMER_CALL:   0.00006  EUR_PUT:  18.58188  AMER_PUT:  20.00148

# %% [markdown]
# ## Convergence Testing - Black-Karasinski

# %% [markdown]
# It is important that the tree price is stable to the number of tree steps. This can be a challenge when pricing American optionality on bonds due to the payment of coupons and the effect of accrued interest on the clean bond price.

# %%
discount_curve = FlatDiscountCurve(value_dt, 0.05)

# %%
issue_dt = Date(1, 9, 2004)
maturity_dt = Date(1, 9, 2025)
coupon = 0.05
freq_type = FrequencyTypes.ANNUAL
dc_type = DayCountTypes.ACT_ACT_ICMA
bond = Bond(issue_dt, maturity_dt, coupon, freq_type, dc_type)
expiry_dt = settle_dt.add_tenor("18m")
face = 100.0

# %%
num_steps_vector = range(50, 500, 10)

# %%
sigma = 0.00001
a = 0.05

# %%
K = 102.0

# %%
vec_ec = []
vec_ac = []
vec_ep = []
vec_ap = []

for num_steps in num_steps_vector:

    bkModel = BKTree(sigma, a, num_steps)

    europeanCallBondOption = BondOption(bond, expiry_dt, K, OptionTypes.EUROPEAN_CALL)
    v_ec = europeanCallBondOption.value(settle_dt, discount_curve, bkModel)

    americanCallBondOption = BondOption(bond, expiry_dt, K, OptionTypes.AMERICAN_CALL)
    v_ac = americanCallBondOption.value(settle_dt, discount_curve, bkModel)

    europeanPutBondOption = BondOption(bond, expiry_dt, K, OptionTypes.EUROPEAN_PUT)
    v_ep = europeanPutBondOption.value(settle_dt, discount_curve, bkModel)

    americanPutBondOption = BondOption(bond, expiry_dt, K, OptionTypes.AMERICAN_PUT)
    v_ap = americanPutBondOption.value(settle_dt, discount_curve, bkModel)

    # print("%d %9.5f %9.5f %9.5f %9.5f"%(num_steps, v_ec, v_ac, v_ep, v_ap))
    vec_ec.append(v_ec)
    vec_ac.append(v_ac)
    vec_ep.append(v_ep)
    vec_ap.append(v_ap)

# %%
plt.plot(num_steps_vector,vec_ec, label="European Bond Call")
plt.legend();

# %%
plt.plot(num_steps_vector,vec_ac, label="American Bond Call")
plt.legend();

# %%
plt.plot(num_steps_vector,vec_ep, label="European Bond Put")
plt.legend();

# %%
plt.plot(num_steps_vector,vec_ap, label="American Bond Put")
plt.legend();

# %% [markdown]
# Copyright (c) 2020 Dominic O'Kane
