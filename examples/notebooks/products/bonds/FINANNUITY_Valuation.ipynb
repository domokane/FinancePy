# %% [markdown]
# # ANNUITY CALCULATOR

# %% [markdown]
# In this notebook I genarate annuity cash flows.

# %%
from financepy.utils import *
# Out:
# #############################################################
# #  FINANCEPY Version 1.1.2 - Built on 25 Sep 2026 at 14:07  #
# #  This software is distributed FREE AND WITHOUT WARRANTY   #
# #  Report issues at https://github.com/domokane/FinancePy   #
# #############################################################

# %%
from financepy.products.bonds.bond_annuity import BondAnnuity
from financepy.products.rates.ibor_swap import IborSwap
from financepy.market.curves.ibor_single_curve import IborSingleCurve

# %% [markdown]
# ## CREATE AN ANNUITY STREAM

# %% [markdown]
# Calculate the cash flows on an annuity

# %%
value_dt = Date(20, 6, 2018)
settle_dt = value_dt

# %%
maturity_dt = settle_dt.add_tenor("5Y")  # Date(20, 9, 2028)
coupon = 0.05
freq_type = FrequencyTypes.SEMI_ANNUAL
cal_type = CalendarTypes.WEEKEND
bd_type = BusDayAdjustTypes.FOLLOWING
dg_type = DateGenRuleTypes.BACKWARD
basis_type = DayCountTypes.ACT_360
face = ONE_MILLION

# %%
annuity = BondAnnuity(maturity_dt,coupon,freq_type,basis_type,cal_type,
                         bd_type,dg_type)

# %%
print(annuity)
# Out:
# OBJECT_TYPE: BondAnnuity
# MATURITY_DATE: 20-JUN-2023
# FREQUENCY: FrequencyTypes.SEMI_ANNUAL
# DC_TYPE: DayCountTypes.ACT_360
# CALENDAR: CalendarTypes.WEEKEND
# BUS_DAY_ADJUST: BusDayAdjustTypes.FOLLOWING
# DATE_GEN_RULE: DateGenRuleTypes.BACKWARD

# %%
face = 1000000

# %%
annuity.print_payments(settle_dt, face)
# Out:
# 20-DEC-2018 , 25416.666666666668
# 20-JUN-2019 , 25277.777777777777
# 20-DEC-2019 , 25416.666666666668
# 22-JUN-2020 , 25694.44444444444
# 21-DEC-2020 , 25277.777777777777
# 21-JUN-2021 , 25277.777777777777
# 20-DEC-2021 , 25277.777777777777
# 20-JUN-2022 , 25277.777777777777
# 20-DEC-2022 , 25416.666666666668
# 20-JUN-2023 , 25277.777777777777

# %% [markdown]
# ## We can value the flows by discounting them

# %% [markdown]
# First we build a Libor swap curve

# %%
depos = []
dc_type = DayCountTypes.ACT_360
fixed_freq = FrequencyTypes.SEMI_ANNUAL
swap_type = SwapTypes.PAY
swap1 = IborSwap(settle_dt,"1Y",swap_type,0.0500,fixed_freq,dc_type)
swap2 = IborSwap(settle_dt,"2Y",swap_type,0.0500,fixed_freq,dc_type)
swap3 = IborSwap(settle_dt,"3Y",swap_type,0.0500,fixed_freq,dc_type)
swap4 = IborSwap(settle_dt,"4Y",swap_type,0.0500,fixed_freq,dc_type)
swap5 = IborSwap(settle_dt,"5Y",swap_type,0.0500,fixed_freq,dc_type)
swaps = [swap1, swap2, swap3, swap4, swap5]

libor_curve = IborSingleCurve(value_dt, depos, [], swaps)

# %%
swap5.value(settle_dt, libor_curve)
# Out:
# -0.0010074992896988988

# %%
swap5.print_fixed_leg_pv()
# Out:
# START DATE: 20-JUN-2018
# MATURITY DATE: 20-JUN-2023
# COUPON (%): 5.0
# FREQUENCY: FrequencyTypes.SEMI_ANNUAL
# DAY COUNT: DayCountTypes.ACT_360
#
# PAYMENTS VALUATION:
# PAY_NUM | PAY_dt      | NOTIONAL | RATE | PMNT     | DF     | PV       | CUM_PV
# --------+-------------+----------+------+----------+--------+----------+----------
#       1 | 20-DEC-2018 |  1000000 |  5.0 | 25416.67 | 0.9752 | 24786.65 |  24786.65
#       2 | 20-JUN-2019 |  1000000 |  5.0 | 25277.78 | 0.9512 | 24043.46 |  48830.11
#       3 | 20-DEC-2019 |  1000000 |  5.0 | 25416.67 | 0.9276 | 23576.38 |  72406.49
#       4 | 22-JUN-2020 |  1000000 |  5.0 | 25694.44 | 0.9044 | 23236.94 |  95643.43
#       5 | 21-DEC-2020 |  1000000 |  5.0 | 25277.78 | 0.8821 | 22296.52 | 117939.95
#       6 | 21-JUN-2021 |  1000000 |  5.0 | 25277.78 | 0.8603 | 21746.81 | 139686.75
#       7 | 20-DEC-2021 |  1000000 |  5.0 | 25277.78 | 0.8391 | 21210.65 |  160897.4
#       8 | 20-JUN-2022 |  1000000 |  5.0 | 25277.78 | 0.8184 | 20687.71 | 181585.11
#       9 | 20-DEC-2022 |  1000000 |  5.0 | 25416.67 | 0.7981 | 20285.76 | 201870.88
#      10 | 20-JUN-2023 |  1000000 |  5.0 | 25277.78 | 0.7785 | 19677.53 |  221548.4

# %% [markdown]
# Here are the flows on the fixed leg of the 5Y swap

# %%
swap5.print_float_leg_pv()
# Out:
# START DATE: 20-JUN-2018
# MATURITY DATE: 20-JUN-2023
# SPREAD (BPS): 0.0
# FREQUENCY: FrequencyTypes.QUARTERLY
# ACCRUAL_DC: DayCountTypes.THIRTY_E_360
#
# PAYMENTS VALUATION:
# PAY_NUM | PAY_dt      | NOTIONAL | IBOR   | PMNT     | DF     | PV       | CUM_PV
# --------+-------------+----------+--------+----------+--------+----------+----------
#       1 | 20-SEP-2018 |  1000000 | 5.0794 | 12698.47 | 0.9875 | 12539.24 |  12539.24
#       2 | 20-DEC-2018 |  1000000 | 5.0238 | 12559.58 | 0.9752 | 12248.25 |  24787.49
#       3 | 20-MAR-2019 |  1000000 | 4.9683 |  12420.7 | 0.9632 | 11964.22 |  36751.71
#       4 | 20-JUN-2019 |  1000000 | 5.0794 | 12698.47 | 0.9512 |  12078.4 |  48830.11
#       5 | 20-SEP-2019 |  1000000 | 5.0789 | 12697.17 | 0.9392 | 11925.75 |  60755.86
#       6 | 20-DEC-2019 |  1000000 | 5.0233 |  12558.3 | 0.9276 | 11649.02 |  72404.88
#       7 | 20-MAR-2020 |  1000000 | 5.0233 |  12558.3 | 0.9161 | 11504.54 |  83909.42
#       8 | 22-JUN-2020 |  1000000 | 5.0772 | 12974.98 | 0.9044 | 11734.01 |  95643.43
#       9 | 21-SEP-2020 |  1000000 | 5.0805 | 12560.01 | 0.8931 | 11217.83 | 106861.26
#      10 | 21-DEC-2020 |  1000000 |  5.024 | 12560.01 | 0.8821 | 11078.68 | 117939.95
#      11 | 22-MAR-2021 |  1000000 | 4.9688 | 12560.01 | 0.8711 | 10941.26 | 128881.21
#      12 | 21-JUN-2021 |  1000000 | 5.0805 | 12560.01 | 0.8603 | 10805.54 | 139686.75
#      13 | 20-SEP-2021 |  1000000 | 5.0805 | 12560.01 | 0.8496 | 10671.51 | 150358.26
#      14 | 20-DEC-2021 |  1000000 |  5.024 | 12560.01 | 0.8391 | 10539.14 |  160897.4
#      15 | 21-MAR-2022 |  1000000 | 4.9688 | 12560.01 | 0.8287 | 10408.41 | 171305.81
#      16 | 20-JUN-2022 |  1000000 | 5.0805 | 12560.01 | 0.8184 |  10279.3 | 181585.11
#      17 | 20-SEP-2022 |  1000000 | 5.0794 | 12698.47 | 0.8082 |  10262.3 | 191847.41
#      18 | 20-DEC-2022 |  1000000 | 5.0238 | 12559.58 | 0.7981 | 10024.15 | 201871.56
#      19 | 20-MAR-2023 |  1000000 | 4.9683 |  12420.7 | 0.7883 |   9791.7 | 211663.26
#      20 | 20-JUN-2023 |  1000000 | 5.0794 | 12698.47 | 0.7785 |  9885.14 |  221548.4

# %%
cleanValue = annuity.clean_price_from_discount_curve(settle_dt, libor_curve)

# %%
dirtyValue = annuity.dirty_price_from_discount_curve(settle_dt, libor_curve)

# %% [markdown]
# The price of the annuity is quoted based on a par notional

# %%
print("CLEAN PRICE:", cleanValue)
print("DIRTY PRICE:", dirtyValue)
print("ACCRD VALUE:", annuity.accrued_int)
# Out:
# CLEAN PRICE: 22154840.29620022
# DIRTY PRICE: 22154840.29620022
# ACCRD VALUE: 0.0

# %% [markdown]
# Copyright (c) 2020 Dominic O'Kane
