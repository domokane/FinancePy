# %% [markdown]
# #  Examination of the FinPolynomialCurve

# %% [markdown]
# The polynomial curve parametrises the zero rate curve

# %%
import numpy as np

# %%
from financepy.market.curves import *
from financepy.utils import *
# Out:
# ####################################################################
# # FINANCEPY BETA Version 0.250 - This build:  23 Sep 2022 at 18:50 #
# #      This software is distributed FREE & WITHOUT ANY WARRANTY    #
# #  Report bugs as issues at https://github.com/domokane/FinancePy  #
# ####################################################################

# %%
import matplotlib.pyplot as plt

# %%
times = np.linspace(0.01, 10.0, 20)
curve_date = Date(2, 2, 2019)
coeffs = [0.04, 0.0002, -0.000010]

# %%
polyCurve = DiscountCurvePoly(curve_date, coeffs)

# %%
dates = curve_date.add_years(times)

# %%
zeros = polyCurve.zero_rate(dates)
fwds = polyCurve.fwd(dates)

# %%
plt.figure(figsize=(8, 6))
plt.plot(times, zeros*100.0, label="Zeros")
plt.plot(times, fwds*100.0, label="Forwards")
plt.xlabel('Time (years)')
plt.ylabel('Zero Rate (%)')
plt.legend(loc='best')

# %% [markdown]
# Copyright (c) 2020 Dominic O'Kane
