# %% [markdown]
# # USING CALENDARS

# %%
from financepy.finutils import *
# Out:
# ####################################################################
# # FINANCEPY BETA Version 0.185 - This build:  30 Oct 2020 at 22:12 #
# #      This software is distributed FREE & WITHOUT ANY WARRANTY    #
# # For info and disclaimer - https://github.com/domokane/FinancePy  #
# #      Send any bug reports or comments to quant@financepy.com     #
# ####################################################################

# %% [markdown]
# We can see what calendars are available

# %%
for e in FinCalendarTypes:
    print(e)
# Out:
# FinCalendarTypes.TARGET
# FinCalendarTypes.US
# FinCalendarTypes.UK
# FinCalendarTypes.WEEKEND
# FinCalendarTypes.JAPAN
# FinCalendarTypes.NONE

# %% [markdown]
# # Holiday Lists

# %%
# Specify US holiday calendar
calUS = Calendar(FinCalendarTypes.US)

# %%
calUS.getHolidayList(2019)
# Out:
# ['TUE 01 JAN 2019',
#  'MON 21 JAN 2019',
#  'MON 18 FEB 2019',
#  'MON 27 MAY 2019',
#  'THU 04 JUL 2019',
#  'MON 02 SEP 2019',
#  'MON 14 OCT 2019',
#  'MON 11 NOV 2019',
#  'THU 28 NOV 2019',
#  'WED 25 DEC 2019']

# %%
# Specify UK holiday calendar
calUK = Calendar(FinCalendarTypes.UK)

# %%
calUK.getHolidayList(2019)
# Out:
# ['TUE 01 JAN 2019',
#  'FRI 19 APR 2019',
#  'MON 22 APR 2019',
#  'MON 06 MAY 2019',
#  'MON 27 MAY 2019',
#  'MON 26 AUG 2019',
#  'WED 25 DEC 2019',
#  'THU 26 DEC 2019']

# %%
# Specify EUROPEAN TARGET holiday calendar
calEU = Calendar(FinCalendarTypes.TARGET)

# %%
calEU.getHolidayList(2019)
# Out:
# ['TUE 01 JAN 2019',
#  'FRI 19 APR 2019',
#  'MON 22 APR 2019',
#  'WED 01 MAY 2019',
#  'WED 25 DEC 2019',
#  'THU 26 DEC 2019']

# %% [markdown]
# ## Easter Monday

# %%
print(calEU.easterMonday(2019))
# Out:
# MON 22 APR 2019

# %%
print(calEU.easterMonday(2018))
# Out:
# MON 02 APR 2018

# %%
print(calEU.easterMonday(2017))
# Out:
# MON 17 APR 2017

# %%
print(calEU.easterMonday(2016))
# Out:
# MON 28 MAR 2016

# %% [markdown]
# Copyright (c) 2020 Dominic O'Kane
