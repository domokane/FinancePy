# %% [markdown]
# # SABR Model for Interest Rates

# %% [markdown]
# We examine the SABR model

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from financepy.utils import *
from financepy.models.sabr import *

# %% [markdown]
# ## SABR Model

# %% [markdown]
# I examine the volatility as a function of strike

# %%
strikes = np.linspace(0.01, 0.10, 100)

# %%
f = 0.032

# %%
t_exp = 2.0

# %%
alpha = 0.174; beta = 1.0; rho = -0.90; nu = 0.817

# %%
model = SABR(alpha, beta, rho, nu)

# %%
model
# Out:
# OBJECT TYPE: SABR
# Alpha: 0.174
# Beta: 1.0
# Nu: 0.817
# Rho: -0.9

# %%
volsSABR = model.black_vol(f, strikes, t_exp) * 100

# %%
plt.figure(figsize=(8,5))
plt.plot(strikes, volsSABR)
plt.title("SABR")
plt.xlabel("Strike")
plt.ylabel("Black Volatility");

# %% [markdown]
# ## Calibration - Fitting to the ATM Vol

# %%
black_vol = 0.22

# %%
f = 0.032

# %%
k = f

# %%
model.set_alpha_from_atm_black_vol(black_vol, k, t_exp)

# %%
model
# Out:
# OBJECT TYPE: SABR
# Alpha: 0.2486852107791646
# Beta: 1.0
# Nu: 0.817
# Rho: -0.9

# %%
model.black_vol(f, k, t_exp) * 100
# Out:
# 22.000000000000004

# %% [markdown]
# The SABR model now fits the ATM volatility exactly

# %%
volsSABR = model.black_vol(f, strikes, t_exp) * 100

# %%
plt.figure(figsize=(8,5))
plt.plot(strikes, volsSABR)
plt.title("SABR")
plt.xlabel("Strike")
plt.ylabel("Black Volatility")
plt.plot(k, black_vol*100, 'o', label="ATM")
plt.legend()

# %% [markdown]
# ## Calibration - Fitting to the Any Strike Vol

# %%
black_vol = 0.26

# %%
f = 0.032

# %%
k = 0.040

# %%
model.set_alpha_from_black_vol(black_vol, f, k, t_exp)

# %%
model
# Out:
# OBJECT TYPE: SABR
# Alpha: 0.3975370245121775
# Beta: 1.0
# Nu: 0.817
# Rho: -0.9

# %%
volsSABR = model.black_vol(f, strikes, t_exp) * 100

# %%
plt.figure(figsize=(8,5))
plt.plot(strikes, volsSABR)
plt.title("SABR")
plt.xlabel("Strike")
plt.ylabel("Black Volatility")
plt.plot(k, black_vol*100, 'o', label="ATM")
plt.legend();

# %% [markdown]
# Copyright (c) 2020 Dominic O'Kane
