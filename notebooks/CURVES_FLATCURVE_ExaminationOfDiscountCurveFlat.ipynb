# %% [markdown]
# # Examination of the FinFlatCurve

# %% [markdown]
# Examine the impact of changing the compunding frequency

# %%
import numpy as np

# %%
from financepy.market.curves.FinDiscountCurveFlat import FinDiscountCurveFlat
from financepy.finutils import *
# Out:
# ###################################################################
# # FINANCEPY BETA Version 0.180 - This build: 06 Sep 2020 at 16:42 #
# #     This software is distributed FREE & WITHOUT ANY WARRANTY    #
# # For info and disclaimer - https://github.com/domokane/FinancePy #
# ###################################################################

# %%
curveDate = FinDate(2, 2, 2019)
times = np.linspace(0.0, 1.0, 5)

# %%
times
# Out:
# array([0.  , 0.25, 0.5 , 0.75, 1.  ])

# %%
dates = curveDate.addYears(times)

# %%
print(dates)
# Out:
# [SAT 02 FEB 2019, THU 02 MAY 2019, FRI 02 AUG 2019, SAT 02 NOV 2019, SUN 02 FEB 2020]

# %%
print("COMPOUNDING", "DFS")
# Out:
# COMPOUNDING DFS

# %%
compounding = FinFrequencyTypes.CONTINUOUS
flatCurve = FinDiscountCurveFlat(curveDate, 0.05, compounding)
dfs = flatCurve.df(dates)
print(compounding, dfs)
# Out:
# FinFrequencyTypes.CONTINUOUS [0.99999995 0.98788224 0.97551034 0.96329338 0.95124082]

# %%
compounding = FinFrequencyTypes.ANNUAL
flatCurve = FinDiscountCurveFlat(curveDate, 0.05, compounding)
dfs = flatCurve.df(dates)
print(compounding, dfs)
# Out:
# FinFrequencyTypes.ANNUAL [0.99999995 0.98817371 0.97609577 0.96416545 0.95239208]

# %%
compounding = FinFrequencyTypes.SEMI_ANNUAL
flatCurve = FinDiscountCurveFlat(curveDate, 0.05, compounding)
dfs = flatCurve.df(dates)
print(compounding, dfs)
# Out:
# FinFrequencyTypes.SEMI_ANNUAL [0.99999995 0.98803034 0.97580778 0.96373642 0.95182566]

# %%
compounding = FinFrequencyTypes.QUARTERLY
flatCurve = FinDiscountCurveFlat(curveDate, 0.05, compounding)
dfs = flatCurve.df(dates)
print(compounding, dfs)
# Out:
# FinFrequencyTypes.QUARTERLY [0.99999995 0.98795689 0.97566027 0.9635167  0.9515356 ]

# %%
compounding = FinFrequencyTypes.MONTHLY
flatCurve = FinDiscountCurveFlat(curveDate, 0.05, compounding)
dfs = flatCurve.df(dates)
print(compounding, dfs)
# Out:
# FinFrequencyTypes.MONTHLY [0.99999995 0.98790726 0.97556059 0.96336823 0.95133961]

# %%
compounding = FinFrequencyTypes.CONTINUOUS
flatCurve = FinDiscountCurveFlat(curveDate, 0.05, compounding)
dfs = flatCurve.df(dates)
print(compounding, dfs)
# Out:
# FinFrequencyTypes.CONTINUOUS [0.99999995 0.98788224 0.97551034 0.96329338 0.95124082]

# %% [markdown]
# Copyright (c) 2020 Dominic O'Kane
