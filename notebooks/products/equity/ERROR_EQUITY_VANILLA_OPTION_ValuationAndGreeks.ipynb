# %% [markdown]
# # ANALYSIS OF EUROPEAN-STYLE CALL AND PUT OPTIONS

# %% [markdown]
# In this notebook I show how you can analyse Vanilla European Call and Put Equity options

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from financepy.finutils import *
from financepy.products.equity import *
from financepy.market.curves import *
# Out:
# ####################################################################
# # FINANCEPY BETA Version 0.191 - This build:  18 Jan 2021 at 12:02 #
# #      This software is distributed FREE & WITHOUT ANY WARRANTY    #
# # For info and disclaimer - https://github.com/domokane/FinancePy  #
# #      Send any bug reports or comments to quant@financepy.com     #
# ####################################################################

# %% [markdown]
# ## Creating the Option

# %% [markdown]
# We need to set up the option details - what you would find in the Term Sheet.

# %%
expiryDate = FinDate(1, 7, 2015)
strikePrice = 100.0

# %% [markdown]
# We now create the option object

# %%
callOption = FinEquityVanillaOption(expiryDate, strikePrice, FinOptionTypes.EUROPEAN_CALL)

# %%
print(callOption)
# Out:
# OBJECT TYPE: FinEquityVanillaOption
# EXPIRY DATE: 01-JUL-2015
# STRIKE PRICE: 100.0
# OPTION TYPE: FinOptionTypes.EUROPEAN_CALL
# NUMBER: 1.0

# %%
putOption = FinEquityVanillaOption(expiryDate, strikePrice, FinOptionTypes.EUROPEAN_PUT)

# %% [markdown]
# ## Valuation

# %% [markdown]
# To do a valuation we need to specify the date and set the market inputs

# %%
valueDate = FinDate(1, 1, 2015)
stockPrice = 90.0
dividendYield = 0.0

# %%
dividendCurve = FinDiscountCurveFlat(valueDate, dividendYield)

# %% [markdown]
# For simplicity the discount curve is assumed to be flat here (we can pass in any discount curve) and is created as follows.

# %%
interestRate = 0.02
discountCurve = FinDiscountCurveFlat(valueDate, interestRate, FinFrequencyTypes.ANNUAL)

# %% [markdown]
# The valuation model we use is Black-Scholes which is passed in as a Black-Scholes model object. It is created as follows.

# %%
volatility = 0.20
model = FinModelBlackScholes(volatility)

# %% [markdown]
# The valuation is as follows and the output is in a dictionary

# %%
callValue = callOption.value(valueDate, stockPrice, discountCurve, dividendCurve, model)
print("Call Option Value: %12.5f" %callValue)
# Out:
# Call Option Value:      1.96752

# %%
putValue = putOption.value(valueDate, stockPrice, discountCurve, dividendCurve, model)
print("Put Option Value: %12.5f" %putValue)
# Out:
# Put Option Value:     10.99034

# %% [markdown]
# ### Spot Price Dependency

# %% [markdown]
# We can examine how the option value depends on the spot price

# %%
stockPrices = np.linspace(60,140,100)
values = callOption.value(valueDate, stockPrices, discountCurve, dividendCurve, model)

# %%
plt.figure(figsize=(10,6))
plt.plot(stockPrices,values, label="Call Option Prices")
plt.xlabel("Stock Prices")
plt.ylabel("Value")
plt.legend()
plt.grid()

# %% [markdown]
# ### Volatility Dependency

# %% [markdown]
# We can see how the value depends on volatility

# %%
volatilities = np.linspace(0.01,10,100)
models = FinModelBlackScholes(volatilities)
values = callOption.value(valueDate, stockPrice, discountCurve, dividendCurve, models)
# Out:
# ==> [ 0.01        0.11090909  0.21181818  0.31272727  0.41363636  0.51454545
#   0.61545455  0.71636364  0.81727273  0.91818182  1.01909091  1.12
#   1.22090909  1.32181818  1.42272727  1.52363636  1.62454545  1.72545455
#   1.82636364  1.92727273  2.02818182  2.12909091  2.23        2.33090909
#   2.43181818  2.53272727  2.63363636  2.73454545  2.83545455  2.93636364
#   3.03727273  3.13818182  3.23909091  3.34        3.44090909  3.54181818
#   3.64272727  3.74363636  3.84454545  3.94545455  4.04636364  4.14727273
#   4.24818182  4.34909091  4.45        4.55090909  4.65181818  4.75272727
#   4.85363636  4.95454545  5.05545455  5.15636364  5.25727273  5.35818182
#   5.45909091  5.56        5.66090909  5.76181818  5.86272727  5.96363636
#   6.06454545  6.16545455  6.26636364  6.36727273  6.46818182  6.56909091
#   6.67        6.77090909  6.87181818  6.97272727  7.07363636  7.17454545
#   7.27545455  7.37636364  7.47727273  7.57818182  7.67909091  7.78
#   7.88090909  7.98181818  8.08272727  8.18363636  8.28454545  8.38545455
#   8.48636364  8.58727273  8.68818182  8.78909091  8.89        8.99090909
#   9.09181818  9.19272727  9.29363636  9.39454545  9.49545455  9.59636364
#   9.69727273  9.79818182  9.89909091 10.        ] <class 'numpy.ndarray'> (<class 'int'>, <class 'float'>, <class 'numpy.float64'>) False
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-1decc33f6fd7> in <module>
#       1 volatilities = np.linspace(0.01,10,100)
# ----> 2 models = FinModelBlackScholes(volatilities)
#       3 values = callOption.value(valueDate, stockPrice, discountCurve, dividendCurve, models)
#
# ~\AppData\Roaming\Python\Python38\site-packages\financepy\models\FinModelBlackScholes.py in __init__(self, volatility, implementationType, numStepsPerYear)
#      33                  numStepsPerYear: int = 100):
#      34
# ---> 35         checkArgumentTypes(self.__init__, locals())
#      36
#      37         self._volatility = volatility
#
# ~\AppData\Roaming\Python\Python38\site-packages\financepy\finutils\FinHelperFunctions.py in checkArgumentTypes(func, values)
#     466             s = f"In {func.__module__}.{func.__name__}:\n"
#     467             s += f"Mismatched Types: expected a "
# --> 468             s += f"{valueName} of type '{usableType.__name__}', however"
#     469             s += f" a value of type '{type(value).__name__}' was given."
#     470             raise FinError(s)
#
# AttributeError: 'tuple' object has no attribute '__name__'

# %%
plt.figure(figsize=(10,6))
plt.plot(volatilities*100,values, label="Option Prices")
plt.xlabel("Volatility (%)")
plt.ylabel("Value")
plt.legend()
plt.grid()

# %% [markdown]
# ### Strike Price Dependency

# %% [markdown]
# Also strikes.

# %%
strikePrices = np.linspace(70,130,50)

# %% [markdown]
# But as these are part of the option description - so we need to first vectorise those.

# %%
callOptions = FinEquityVanillaOption(expiryDate, strikePrices, FinOptionTypes.EUROPEAN_CALL)

# %% [markdown]
# Look, we have an array of callOptions with different strikes

# %%
callOptions._strikePrice
# Out:
# array([ 70.        ,  71.2244898 ,  72.44897959,  73.67346939,
#         74.89795918,  76.12244898,  77.34693878,  78.57142857,
#         79.79591837,  81.02040816,  82.24489796,  83.46938776,
#         84.69387755,  85.91836735,  87.14285714,  88.36734694,
#         89.59183673,  90.81632653,  92.04081633,  93.26530612,
#         94.48979592,  95.71428571,  96.93877551,  98.16326531,
#         99.3877551 , 100.6122449 , 101.83673469, 103.06122449,
#        104.28571429, 105.51020408, 106.73469388, 107.95918367,
#        109.18367347, 110.40816327, 111.63265306, 112.85714286,
#        114.08163265, 115.30612245, 116.53061224, 117.75510204,
#        118.97959184, 120.20408163, 121.42857143, 122.65306122,
#        123.87755102, 125.10204082, 126.32653061, 127.55102041,
#        128.7755102 , 130.        ])

# %% [markdown]
# Then we can get back a vector of values

# %%
callValues = callOptions.value(valueDate, stockPrice, discountCurve, dividendCurve, model)

# %%
plt.figure(figsize=(10,6))
plt.plot(strikePrices, callValues, label="CALL Option Prices")
plt.xlabel("Strike Price")
plt.ylabel("Value")
plt.legend()
plt.grid()

# %% [markdown]
# Let's do put options too

# %%
putOptions = FinEquityVanillaOption(expiryDate, strikePrices, FinOptionTypes.EUROPEAN_PUT)

# %%
putValues = putOptions.value(valueDate, stockPrice, discountCurve, dividendCurve, model)

# %%
plt.figure(figsize=(10,6))
plt.plot(strikePrices, putValues, label="PUT Option Prices")
plt.xlabel("Strike Price")
plt.ylabel("Value")
plt.legend()
plt.grid()

# %% [markdown]
# ## Risk Sensitivities

# %%
callDeltas = callOption.delta(valueDate, stockPrices, discountCurve, dividendCurve, model)

# %%
plt.figure(figsize=(10,6))
plt.plot(stockPrices, callDeltas, label="CALL Delta")
plt.xlabel("Stock Price")
plt.ylabel("Value")
plt.legend()
plt.grid()

# %%
callGammas = callOption.gamma(valueDate, stockPrices, discountCurve, dividendCurve, model)

# %%
plt.figure(figsize=(10,6))
plt.plot(stockPrices, callGammas, label="CALL Gamma")
plt.xlabel("Stock Price")
plt.ylabel("Value")
plt.legend()
plt.grid()

# %%
callVegas = callOption.vega(valueDate, stockPrices, discountCurve, dividendCurve, model)

# %%
plt.figure(figsize=(10,6))
plt.plot(stockPrices, callVegas, label="CALL Vega")
plt.xlabel("Stock Price")
plt.ylabel("Value")
plt.legend()
plt.grid()

# %%
callThetas = callOption.theta(valueDate, stockPrices, discountCurve, dividendCurve, model)

# %%
plt.figure(figsize=(10,6))
plt.plot(stockPrices, callThetas, label="CALL Theta")
plt.xlabel("Stock Price")
plt.ylabel("Value")
plt.legend()
plt.grid()

# %% [markdown]
# Copyright (c) 2019, Dominic O'Kane
